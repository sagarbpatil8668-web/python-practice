# %%
print("hello")
# Out:
# hello

# %%
a = 22
b = 3
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a//b) # division without decimal
print(a%b) # module. means baki
# Out:
# 25
# 19
# 66
# 7.333333333333333
# 7
# 1

# %%
print("will complete it")
# Out:
# will complete it
